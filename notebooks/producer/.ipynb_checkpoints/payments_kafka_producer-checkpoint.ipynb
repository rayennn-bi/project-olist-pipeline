# %% [markdown]
# # Orders Kafka Producer

# %% [markdown]
# ## 1. Start Spark

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName('olist-kafka-producer')
    .master('local[*]')
    .config(
        'spark.jars.packages',
        'org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.1,org.postgresql:postgresql:42.7.3'
    )
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://f3172a5d41c9:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>olist-kafka-producer</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os

DATA_PATH = os.getenv('DATA_PATH')
RAW_PATH = os.getenv('RAW_PATH')

print('DATA_PATH =', DATA_PATH)
print('RAW_PATH =', RAW_PATH)
# Out:
# DATA_PATH = /home/jovyan/work/data
# RAW_PATH = /home/jovyan/work/data/raw

# %%
orders_df = spark.read.csv(
    f"{RAW_PATH}/orders/olist_orders_dataset.csv",
    header=True,
    inferSchema=True
)

orders_df.printSchema()
orders_df.show(5, truncate=False)
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)
#
# +--------------------------------+--------------------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |order_id                        |customer_id                     |order_status|order_purchase_timestamp|order_approved_at  |order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# ...

# %% [markdown]
# # 3. Clean and cast

# %%
from pyspark.sql import functions as F

orders_clean_df = (
    orders_df
    .select(
        F.col('order_id').cast('string'),
        F.col('customer_id').cast('string'),
        F.col('order_status').cast('string'),
        F.to_timestamp('order_purchase_timestamp').alias('order_purchase_timestamp'),
        F.to_timestamp('order_approved_at').alias('order_approved_at'),
        F.to_timestamp('order_delivered_carrier_date').alias('order_delivered_carrier_date'),
        F.to_timestamp('order_delivered_customer_date').alias('order_delivered_customer_date'),
        F.to_timestamp('order_estimated_delivery_date').alias('order_estimated_delivery_date'),
    )
)

orders_clean_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)

# %% [markdown]
# # 4. Validate and deduplicate

# %%
orders_valid_df = (
    orders_clean_df
    .filter(F.col('order_id').isNotNull())
    .filter(F.col('customer_id').isNotNull())
    .dropDuplicates(['order_id'])
)

print('raw orders count:', orders_df.count())
print('valid deduplicated orders count:', orders_valid_df.count())
# Out:
# raw orders count: 99441
# valid deduplicated orders count: 99441

# %% [markdown]
# # 5. Order by shipping date

# %%
orders_kafka_df = (
    orders_valid_df
    .orderBy(F.col('order_purchase_timestamp').asc_nulls_last())
)

orders_kafka_df.select(
    'order_id',
    'customer_id',
    'order_status',
    'order_purchase_timestamp'
).show(5, truncate=False)
# Out:
# +--------------------------------+--------------------------------+------------+------------------------+
# |order_id                        |customer_id                     |order_status|order_purchase_timestamp|
# +--------------------------------+--------------------------------+------------+------------------------+
# |2e7a8482f6fb09756ca50c10d7bfc047|08c5351a6aca1c1589a38f244edeee9d|shipped     |2016-09-04 21:15:19     |
# |e5fa5a7210941f7d56d0208e4e071d35|683c54fc24d40ee9f8a6fc179fd9856c|canceled    |2016-09-05 00:15:34     |
# |809a282bbd5dbcabb6f2f724fca862ec|622e13439d6b5a0b486c435618b2679e|canceled    |2016-09-13 15:24:19     |
# |bfbd0f9bdef84302105ad712db648a6c|86dc2ffce2dfff336de2f386a786e574|delivered   |2016-09-15 12:16:38     |
# |71303d7e93b399f5bcd537d124c0bcfa|b106b360fe2ef8849fbbd056f777b4d5|canceled    |2016-10-02 22:07:52     |
# +--------------------------------+--------------------------------+------------+------------------------+
# only showing top 5 rows

# %% [markdown]
# # 6. Convert Spark rows to Python dicts

# %%
orders_for_kafka = [
    {
        'order_id': row['order_id'],
        'customer_id': row['customer_id'],
        'order_status': row['order_status'],
        'order_purchase_timestamp': row['order_purchase_timestamp'].isoformat() if row['order_purchase_timestamp'] else None,
        'order_approved_at': row['order_approved_at'].isoformat() if row['order_approved_at'] else None,
        'order_delivered_carrier_date': row['order_delivered_carrier_date'].isoformat() if row['order_delivered_carrier_date'] else None,
        'order_delivered_customer_date': row['order_delivered_customer_date'].isoformat() if row['order_delivered_customer_date'] else None,
        'order_estimated_delivery_date': row['order_estimated_delivery_date'].isoformat() if row['order_estimated_delivery_date'] else None,
    }
    for row in orders_kafka_df.collect()
]

print('records prepared for kafka:', len(orders_for_kafka))
orders_for_kafka[0]

# %% [markdown]
# # 7. Create Kafka producer

# %%
import json
from kafka import KafkaProducer

producer = KafkaProducer(
    bootstrap_servers='kafka:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8'),
    key_serializer=lambda v: v.encode('utf-8') if v else None,
)

print('Producer ready')
# Out:
# Producer ready

# %% [markdown]
# # 8. Send a small sample first

# %%
sample_n = 10

for record in order_items_for_kafka[:sample_n]:
    message_key = f"{record['order_id']}_{record['order_item_id']}"
    producer.send('olist.order_items', key=message_key, value=record)

producer.flush()
print(f'Sent {sample_n} sample messages')
# Out:
# Sent 10 sample messages

# %% [markdown]
# # 9. Send all messages

# %%
for i, record in enumerate(order_items_for_kafka, start=1):
    message_key = f"{record['order_id']}_{record['order_item_id']}"
    producer.send('olist.order_items', key=message_key, value=record)

    if i % 5000 == 0:
        producer.flush()
        print(f'Sent {i} messages')

producer.flush()
print(f'All messages sent: {len(order_items_for_kafka)}')
# Out:
# Sent 5000 messages
# Sent 10000 messages
# Sent 15000 messages
# Sent 20000 messages
# Sent 25000 messages
# Sent 30000 messages
# Sent 35000 messages
# Sent 40000 messages
# Sent 45000 messages
# Sent 50000 messages
# Sent 55000 messages
# Sent 60000 messages
# Sent 65000 messages
# Sent 70000 messages
# Sent 75000 messages
# Sent 80000 messages
# Sent 85000 messages
# Sent 90000 messages
# Sent 95000 messages
# Sent 100000 messages
# Sent 105000 messages
# Sent 110000 messages
# All messages sent: 112650

# %% [markdown]
# # 10. Close producer

# %%
producer.close()
print('Producer closed')
# Out:
# Producer closed
