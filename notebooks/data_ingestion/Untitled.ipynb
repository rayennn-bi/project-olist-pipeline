# %% [markdown]
# ## 1. Start spark

# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession.builder
    .appName("olist-test")
    .master("local[*]")
    .config(
        "spark.jars.packages",
        "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.1,org.postgresql:postgresql:42.7.3"
    )
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://0bc1ca93fd6c:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>olist-test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os

DATA_PATH = os.getenv('DATA_PATH', '/home/jovyan/work/data')
RAW_PATH = f"{DATA_PATH}/raw"
CHECKPOINT_PATH = f"{DATA_PATH}/checkpoint"

print('DATA_PATH =', DATA_PATH)
print('RAW_PATH =', RAW_PATH)
print('CHECKPOINT_PATH =', CHECKPOINT_PATH)
# Out:
# DATA_PATH = /home/jovyan/work/data
# RAW_PATH = /home/jovyan/work/data/raw
# CHECKPOINT_PATH = /home/jovyan/work/data/checkpoint
