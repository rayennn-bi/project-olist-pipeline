# %%
import pandas as pd

def run():
    df = pd.read_csv('/opt/airflow/data/dwh/fact_sales.csv')

    assert df.shape[0] > 0, "Fact table is empty"

    print("Quality check passed: fact_sales")

if __name__ == "__main__":
    run()
