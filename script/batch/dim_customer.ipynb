# %%
import pandas as pd

def run():
    df = pd.read_csv('/opt/airflow/data/raw/olist_customers_dataset.csv')

    df_dim = df[['customer_id', 'customer_city', 'customer_state']].drop_duplicates()

    df_dim.to_csv('/opt/airflow/data/dwh/dim_customer.csv', index=False)

    print("dim_customer created")

if __name__ == "__main__":
    run()
